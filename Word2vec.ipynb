# %%
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import gensim

# %%
from gensim.models import Word2Vec

# %%
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv['king']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-572c69f270b7> in <module>
# ----> 1 wv['king']
#
# NameError: name 'wv' is not defined

# %%
wv.similar_by_word('king')
# Out:
# [('kings', 0.7138046026229858),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864822864532471),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.543294370174408),
#  ('throne', 0.5422104597091675)]

# %%
wv.similarity('princes','prince')
# Out:
# 0.7053308

# %%
S
